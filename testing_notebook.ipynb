# %% [markdown]
# # Testing Notebook for GAN Experiments

# %%
import torch
from diffuser import main, TimeEmbedding

# %%
main("models/unet4.pt")
# Out:
# epoch: 0
# 0	 ℒ = 11.3816
# saving...
# saved.
# 1	 ℒ = 29.3488
# 2	 ℒ = 18.1302
# 3	 ℒ = 17.3646
# 4	 ℒ = 21.0527
# 5	 ℒ = 13.9148
# 6	 ℒ = 5.5156
# 7	 ℒ = 13.7708
# 8	 ℒ = 13.6458
# 9	 ℒ = 7.7473
# 10	 ℒ = 5.9441
# 11	 ℒ = 10.8500
# 12	 ℒ = 5.5157
# 13	 ℒ = 15.6226
# 14	 ℒ = 6.4902
# 15	 ℒ = 8.4743
# 16	 ℒ = 8.6672
# 17	 ℒ = 5.4154
# 18	 ℒ = 5.0964
# 19	 ℒ = 14.8377
# 20	 ℒ = 8.5262
# 21	 ℒ = 7.3874
# 22	 ℒ = 12.2134
# 23	 ℒ = 9.1998
# 24	 ℒ = 7.8841
# 25	 ℒ = 6.5054
# 26	 ℒ = 7.1170
# 27	 ℒ = 6.2861
# 28	 ℒ = 6.4018
# 29	 ℒ = 7.7666
# 30	 ℒ = 5.3334
# 31	 ℒ = 8.4473
# 32	 ℒ = 8.2571
# 33	 ℒ = 5.4503
# 34	 ℒ = 3.5724
# 35	 ℒ = 10.7496
# 36	 ℒ = 6.7651
# 37	 ℒ = 5.6174
# 38	 ℒ = 2.9769
# 39	 ℒ = 9.5967
# 40	 ℒ = 6.5486
# 41	 ℒ = 5.0132
# 42	 ℒ = 10.0867
# 43	 ℒ = 4.2134
# 44	 ℒ = 5.0546
# 45	 ℒ = 3.2263
# 46	 ℒ = 3.6518
# 47	 ℒ = 4.3435
# 48	 ℒ = 6.4437
# 49	 ℒ = 8.2282
# 50	 ℒ = 2.6657
# 51	 ℒ = 5.7811
# 52	 ℒ = 3.1177
# 53	 ℒ = 3.7574
# 54	 ℒ = 3.6359
# 55	 ℒ = 5.3250
# ...
