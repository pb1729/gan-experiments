# %% [markdown]
# # Testing Notebook for GAN Experiments

# %%
import torch
from base_wgan import main

# %%
main("models/bwg1.pt")
# Out:
# 0	 ℒᴰ = 0.131511	 ℒᴳ = 5.075219
# saving...
# saved.
# 1	 ℒᴰ = 7.580807	 ℒᴳ = -2.352084
# 2	 ℒᴰ = 10.841098	 ℒᴳ = -0.601273
# 3	 ℒᴰ = 0.059460	 ℒᴳ = 0.348973
# 4	 ℒᴰ = 0.056134	 ℒᴳ = 0.042205
# 5	 ℒᴰ = -0.024969	 ℒᴳ = 0.013465
# 6	 ℒᴰ = -0.145172	 ℒᴳ = 0.312898
# 7	 ℒᴰ = -0.295747	 ℒᴳ = 0.359669
# 8	 ℒᴰ = -0.237636	 ℒᴳ = 0.183113
# 9	 ℒᴰ = -0.213722	 ℒᴳ = 0.243678
# 10	 ℒᴰ = -0.256877	 ℒᴳ = 0.292177
# 11	 ℒᴰ = -0.192429	 ℒᴳ = 0.117273
# 12	 ℒᴰ = -0.189032	 ℒᴳ = 0.255265
# 13	 ℒᴰ = 0.164901	 ℒᴳ = -1.183927
# 14	 ℒᴰ = 2.464497	 ℒᴳ = 1.423045
# 15	 ℒᴰ = 1.544264	 ℒᴳ = 0.563546
# 16	 ℒᴰ = -0.196757	 ℒᴳ = 0.002961
# 17	 ℒᴰ = -0.022801	 ℒᴳ = 0.478158
# 18	 ℒᴰ = -0.271404	 ℒᴳ = 0.781324
# 19	 ℒᴰ = 0.002561	 ℒᴳ = 0.424638
# 20	 ℒᴰ = -0.110511	 ℒᴳ = 0.254507
# 21	 ℒᴰ = -0.101715	 ℒᴳ = 0.706445
# 22	 ℒᴰ = -0.122406	 ℒᴳ = 0.621825
# 23	 ℒᴰ = -0.060329	 ℒᴳ = 0.179024
# 24	 ℒᴰ = -0.043913	 ℒᴳ = 0.810933
# 25	 ℒᴰ = -0.038058	 ℒᴳ = 0.527312
# 26	 ℒᴰ = -0.192793	 ℒᴳ = 0.573262
# ...
