# %% [markdown]
# # Testing Notebook for GAN Experiments

# %%
import torch
from cifar10_wgan import main
# Out:
# Files already downloaded and verified

# %%
main("models/cifar10_wgan1.pt")
# Out:
# 0	 ℒᴰ = 0.519967	 ℒᴳ = 2.943952
# saving...
# saved.
# 1	 ℒᴰ = 1.796214	 ℒᴳ = -0.251506
# 2	 ℒᴰ = 3.477645	 ℒᴳ = -0.323418
# 3	 ℒᴰ = 0.317385	 ℒᴳ = 0.169070
# 4	 ℒᴰ = 0.307510	 ℒᴳ = 0.091349
# 5	 ℒᴰ = 0.014357	 ℒᴳ = 0.046466
# 6	 ℒᴰ = 0.173758	 ℒᴳ = 0.095761
# 7	 ℒᴰ = 0.043796	 ℒᴳ = 0.285587
# 8	 ℒᴰ = 0.064494	 ℒᴳ = 0.209304
# 9	 ℒᴰ = 0.159136	 ℒᴳ = 0.502807
# 10	 ℒᴰ = 0.102349	 ℒᴳ = 0.300594
# 11	 ℒᴰ = 0.091912	 ℒᴳ = 0.620226
# 12	 ℒᴰ = 0.085082	 ℒᴳ = 0.228406
# 13	 ℒᴰ = 0.108962	 ℒᴳ = 0.689707
# 14	 ℒᴰ = 0.087402	 ℒᴳ = -0.001903
# 15	 ℒᴰ = 0.376426	 ℒᴳ = 0.734491
# 16	 ℒᴰ = 0.130297	 ℒᴳ = 0.280578
# 17	 ℒᴰ = 0.095418	 ℒᴳ = 0.484663
# 18	 ℒᴰ = 0.016531	 ℒᴳ = 0.144261
# 19	 ℒᴰ = 0.083978	 ℒᴳ = 0.721971
# 20	 ℒᴰ = 0.045344	 ℒᴳ = -0.078784
# 21	 ℒᴰ = 0.272898	 ℒᴳ = 0.590068
# 22	 ℒᴰ = 0.230479	 ℒᴳ = -0.231570
# 23	 ℒᴰ = 0.133448	 ℒᴳ = 0.424844
# 24	 ℒᴰ = 0.114765	 ℒᴳ = -0.028707
# 25	 ℒᴰ = 0.030723	 ℒᴳ = 0.171383
# 26	 ℒᴰ = -0.042069	 ℒᴳ = 0.147818
# 27	 ℒᴰ = -0.030173	 ℒᴳ = -0.054679
# ...
